# %% [markdown]
# df.sort_values(by="kolumna"/[lista kolumn], na_position="last/"first", ascending=t/f lub [t/f, t/f ...], kind="‘quicksort’, ‘mergesort’, ‘heapsort’, ‘stable’")
#
# df.sort_index(dodatkowe argumenty dla multiindex - to potem)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %%
fuel = pd.read_csv(r"..\course-files\fuel.csv", usecols=['Vehicle ID','Year','Make','Model','Class','Fuel Type','Combined MPG (FT1)'],
                  index_col="Vehicle ID", low_memory=False)
fuel.head()
# Out:
#             Year        Make               Model                        Class
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars  \
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                21.0
# 27550        Regular                17.0

# %%
fuel.loc[27681, "Combined MPG (FT1)"] = np.NaN
fuel.head()
# Out:
#             Year        Make               Model                        Class
# Vehicle ID
# 26587       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars  \
# 27705       1984  Alfa Romeo           GT V6 2.5             Minicompact Cars
# 26561       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27681       1984  Alfa Romeo  Spider Veloce 2000                  Two Seaters
# 27550       1984  AM General   DJ Po Vehicle 2WD  Special Purpose Vehicle 2WD
#
#            Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 26587        Regular                20.0
# 27705        Regular                20.0
# 26561        Regular                21.0
# 27681        Regular                 NaN
# 27550        Regular                17.0

# %%
fuel.sort_values(by=["Make","Model"]).head(50)
# Out:
#             Year              Make                Model
# Vehicle ID
# 27550       1984        AM General    DJ Po Vehicle 2WD  \
# 28426       1984        AM General    DJ Po Vehicle 2WD
# 27549       1984        AM General     FJ8c Post Office
# 28425       1984        AM General     FJ8c Post Office
# 1032        1985        AM General  Post Office DJ5 2WD
# 1033        1985        AM General  Post Office DJ8 2WD
# 3347        1987  ASC Incorporated                  GNX
# 13309       1997             Acura          2.2CL/3.0CL
# 13311       1997             Acura          2.2CL/3.0CL
# 13310       1997             Acura          2.2CL/3.0CL
# 14038       1998             Acura          2.3CL/3.0CL
# 14040       1998             Acura          2.3CL/3.0CL
# 14039       1998             Acura          2.3CL/3.0CL
# 14834       1999             Acura          2.3CL/3.0CL
# 14836       1999             Acura          2.3CL/3.0CL
# ...

# %%
fuel.sort_values(by="Combined MPG (FT1)", ascending=False).head(20)
# Out:
#             Year             Make                            Model
# Vehicle ID
# 31673       2012       Mitsubishi                           i-MiEV  \
# 32278       2012             Ford                   Focus Electric
# 32276       2011              BMW                         Active E
# 30979       2011           Nissan                             Leaf
# 30978       2008             MINI                            MiniE
# 31065       2011            smart      fortwo electric drive coupe
# 31064       2011            smart  fortwo electric drive cabriolet
# 30968       1999              GMC                              EV1
# 16423       2000           Nissan                         Altra EV
# 18290       2002           Toyota                          RAV4 EV
# 19296       2003           Toyota                          RAV4 EV
# 17331       2001           Nissan                       Hyper-Mini
# 32277       2012  CODA Automotive                             CODA
# ...

# %%
fuel.sort_values(by=["Make", "Combined MPG (FT1)"], ascending=[True, False]).head()
# Out:
#             Year        Make                Model
# Vehicle ID
# 27550       1984  AM General    DJ Po Vehicle 2WD  \
# 28426       1984  AM General    DJ Po Vehicle 2WD
# 1032        1985  AM General  Post Office DJ5 2WD
# 27549       1984  AM General     FJ8c Post Office
# 28425       1984  AM General     FJ8c Post Office
#
#                                   Class Fuel Type  Combined MPG (FT1)
# Vehicle ID
# 27550       Special Purpose Vehicle 2WD   Regular                17.0
# 28426       Special Purpose Vehicle 2WD   Regular                17.0
# 1032        Special Purpose Vehicle 2WD   Regular                16.0
# 27549       Special Purpose Vehicle 2WD   Regular                13.0
# 28425       Special Purpose Vehicle 2WD   Regular                13.0

# %%
fuel.sort_values("Combined MPG (FT1)", na_position="first").head()
# Out:
#             Year         Make               Model        Class Fuel Type
# Vehicle ID
# 27681       1984   Alfa Romeo  Spider Veloce 2000  Two Seaters   Regular  \
# 32106       2012    Mitsubish                 NaN          NaN       NaN
# 2914        1987  Lamborghini            Countach  Two Seaters   Premium
# 6413        1990  Lamborghini            Countach  Two Seaters   Premium
# 5267        1989  Lamborghini            Countach  Two Seaters   Premium
#
#             Combined MPG (FT1)
# Vehicle ID
# 27681                      NaN
# 32106                      NaN
# 2914                       7.0
# 6413                       7.0
# 5267                       7.0

# %%
fuel.sort_values("Combined MPG (FT1)", na_position="first", inplace=True)
fuel.head()
# Out:
#             Year         Make               Model        Class Fuel Type
# Vehicle ID
# 27681       1984   Alfa Romeo  Spider Veloce 2000  Two Seaters   Regular  \
# 32106       2012    Mitsubish                 NaN          NaN       NaN
# 2914        1987  Lamborghini            Countach  Two Seaters   Premium
# 6413        1990  Lamborghini            Countach  Two Seaters   Premium
# 5267        1989  Lamborghini            Countach  Two Seaters   Premium
#
#             Combined MPG (FT1)
# Vehicle ID
# 27681                      NaN
# 32106                      NaN
# 2914                       7.0
# 6413                       7.0
# 5267                       7.0

# %%
fuel.sort_values("Vehicle ID").head()
# Out:
#             Year        Make               Model        Class Fuel Type
# Vehicle ID
# 1           1985  Alfa Romeo  Spider Veloce 2000  Two Seaters   Regular  \
# 2           1985     Bertone                X1/9  Two Seaters   Regular
# 3           1985   Chevrolet            Corvette  Two Seaters   Regular
# 4           1985   Chevrolet            Corvette  Two Seaters   Regular
# 5           1985      Nissan               300ZX  Two Seaters   Regular
#
#             Combined MPG (FT1)
# Vehicle ID
# 1                         21.0
# 2                         22.0
# 3                         17.0
# 4                         17.0
# 5                         16.0
