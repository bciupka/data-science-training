# %% [markdown]
# groups.mean() - wylicza średnie dla wszystkich grup jako df
#
# groups.sum()
#
# groups.count() - nie NaN
#
# groups.min() - zbiera min z każdej kolumny (taki wiersz nie istnieje w oryginalnym df). Najlepiej używać funkcji agregujących po zdefiniowaniu kolumny - groups[kolumna / [kolumny]].f.agregujaca()
#
# groups.max()
#
# mean sie wysypie jeżeli są nienumeryczne wartości

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math

# %matplotlib inline

# %%
from datetime import datetime
from datetime import timedelta
import time

# %%
df = pd.read_csv('../course-files/marathon_results_2016.csv', index_col='Bib',
usecols=['Bib','40K','Half','Pace','Age','M/F','Country',
'State','City'])
df = df[(df['40K'] != '-') & (df['Half'] != '-')]
df['40K'] = df['40K'].apply(pd.to_timedelta)
df['Half'] = df['Half'].apply(pd.to_timedelta)
df['TotalSeconds'] = df['40K'].apply(lambda x: timedelta.total_seconds(x))
df['HalfSeconds'] = df['Half'].apply(lambda x: timedelta.total_seconds(x))
df.head()
# Out:
#      Age M/F         City State Country            Half             40K
# Bib
# 5     21   M  Addis Ababa   NaN     ETH 0 days 01:06:45 0 days 02:05:59  \
# 1     26   M         Ambo   NaN     ETH 0 days 01:06:46 0 days 02:05:59
# 6     31   M  Addis Ababa   NaN     ETH 0 days 01:06:44 0 days 02:06:47
# 11    33   M       Kitale   NaN     KEN 0 days 01:06:46 0 days 02:06:47
# 14    23   M      Eldoret   NaN     KEN 0 days 01:06:46 0 days 02:08:11
#
#         Pace  TotalSeconds  HalfSeconds
# Bib
# 5    0:05:04        7559.0       4005.0
# 1    0:05:06        7559.0       4006.0
# 6    0:05:07        7607.0       4004.0
# 11   0:05:07        7607.0       4006.0
# 14   0:05:11        7691.0       4006.0

# %%
group_city = df.groupby('City')

# %%
group_city.mean().head() #nie działa
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\ops.py:959, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
# ...

# %%
group_city[['TotalSeconds', 'HalfSeconds']].mean().head()
# Out:
#                   TotalSeconds  HalfSeconds
# City
# 0851 Oslo              11724.0       5731.0
# 20832                  11640.0       5757.0
# 34-120 Andrychow       14111.0       6699.5
# 5700 Svendborg         13498.0       6552.0
# 95630                  13043.0       6625.0

# %%
group_city.TotalSeconds.mean().to_frame().head()
# Out:
#                   TotalSeconds
# City
# 0851 Oslo              11724.0
# 20832                  11640.0
# 34-120 Andrychow       14111.0
# 5700 Svendborg         13498.0
# 95630                  13043.0

# %%
group_age = df.groupby('Age')

# %%
group_age.count().head()
# Out:
#      M/F  City  State  Country  Half  40K  Pace  TotalSeconds  HalfSeconds
# Age
# 18    22    22     22       22    22   22    22            22           22
# 19    41    41     41       41    41   41    41            41           41
# 20    84    84     82       84    84   84    84            84           84
# 21   159   159    155      159   159  159   159           159          159
# 22   226   226    222      226   226  226   226           226          226

# %%
group_age.TotalSeconds.count().head()
# Out:
# Age
# 18     22
# 19     41
# 20     84
# 21    159
# 22    226
# Name: TotalSeconds, dtype: int64
